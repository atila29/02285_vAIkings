# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv("summary.csv")
print(df1)
# Out:
#              lvl_name lvl_solved  actions_used  last_action_time (in seconds)
# 0             MAMulle        No.      321743.0                         90.000
# 1           MAAIstars        No.         466.0                         89.678
# 2         MAdeepChaos       Yes.         451.0                          5.496
# 3             SAMulle        No.       42557.0                         90.000
# 4              SAIIOO       Yes.          21.0                          2.895
# 5          MAaiaicapn       Yes.        1168.0                          3.897
# 6          SADeepPlan       Yes.         352.0                          2.125
# 7             MAKaren        No.        1954.0                         89.979
# 8           MAThreePO       Yes.         222.0                          0.416
# 9         SAChuligans       Yes.         216.0                          0.378
# 10  MAOptimalSolution       Yes.           5.0                          0.049
# ...

# %%
temp = df1[df1['lvl_solved'] == 'Yes.'].sort_values(["actions_used"])
temp
# Out:
#              lvl_name lvl_solved  actions_used  last_action_time (in seconds)
# 10  MAOptimalSolution       Yes.           5.0                          0.049
# 59             SAheav       Yes.          11.0                          0.004
# 48           SAaiaioh       Yes.          11.0                          0.009
# 17           MAaiaioh       Yes.          13.0                          0.025
# 4              SAIIOO       Yes.          21.0                          2.895
# 27            SAThree       Yes.          21.0                          0.053
# 42        SAaicecubes       Yes.          27.0                          0.010
# 39          MACoronAI       Yes.          29.0                          0.118
# 43           MAHoldUd       Yes.          30.0                          0.159
# 18         MAMSecretA       Yes.          34.0                          0.072
# 55         SAMSecretA       Yes.          36.0                          0.031
# ...

# %%
len(temp)
# Out:
# 39

# %%
ax = temp.plot(kind='scatter',x='last_action_time (in seconds)',y='actions_used',color='red')
