# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Using cached pandas-1.0.3-cp38-cp38-manylinux1_x86_64.whl (10.0 MB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/lib/python3.8/site-packages (from pandas) (1.18.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/mp/.local/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.0.3

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv("summary.csv")
print(df1)
# Out:
#              lvl_name lvl_solved  actions_used  last_action_time (in seconds)
# 0             MAMulle       Yes.         158.0                          0.548
# 1           MAAIstars        No.         713.0                        179.957
# 2         MAdeepChaos       Yes.         451.0                          5.618
# 3             SAMulle        No.       38196.0                        179.996
# 4              SAIIOO       Yes.          18.0                          1.573
# 5          MAaiaicapn        No.         476.0                        179.879
# 6          SADeepPlan       Yes.         337.0                          1.567
# 7             MAKaren        No.       46842.0                        178.919
# 8           MAThreePO       Yes.         221.0                          0.829
# 9         SAChuligans       Yes.         216.0                          0.333
# 10  MAOptimalSolution       Yes.           5.0                          0.044
# 11        MAfootsteps        No.         771.0                        179.840
# 12          SAThreePO       Yes.         164.0                          0.354
# 13          SANeverAI       Yes.         391.0                          0.405
# 14        SABaguettes        No.        2480.0                        179.819
# 15          MANeverAI       Yes.         147.0                          1.040
# 16        MAaicecubes       Yes.         130.0                          0.207
# 17           MAaiaioh       Yes.          13.0                          0.019
# 18         MAMSecretA       Yes.          34.0                          0.106
# 19          SANicolAI       Yes.         130.0                          0.114
# 20          MANicolAI        No.        3191.0                        179.933
# 21         SAAIAIcapn       Yes.         941.0                         35.085
# 22           SAReftAI        No.          47.0                        178.999
# 23         SATrueGlue       Yes.         110.0                          0.137
# 24        SAdeepChaos       Yes.         521.0                          5.104
# 25           SATheZoo       Yes.         203.0                          0.444
# 26           SAFPHPOP        No.         480.0                        178.420
# 27            SAThree       Yes.          21.0                          0.135
# 28            MAThree        No.      334928.0                        180.000
# 29         MAMAAIStro       Yes.          56.0                          0.037
# 30         MADeepPlan        No.         277.0                        179.903
# 31        SAAIcaramba        No.       79317.0                        180.000
# 32         MAVAikings       Yes.         866.0                        148.809
# 33           MATheZoo        No.        1284.0                        179.955
# 34         SASokoBros        No.        1225.0                        179.999
# 35         MATrueGlue       Yes.          74.0                          0.310
# 36            SAKaren       Yes.         497.0                         40.125
# 37           MAFPHPOP        No.         280.0                        179.146
# 38        MADeepMinds        No.        5581.0                        179.986
# 39          MACoronAI       Yes.          28.0                          0.092
# 40        SABoxAgents        No.      158077.0                        180.000
# 41        MABaguettes       Yes.         213.0                         12.790
# 42        SAaicecubes       Yes.          27.0                          0.012
# 43           MAHoldUd       Yes.          24.0                          0.119
# 44           SAHoldUd        No.          58.0                        177.699
# 45             MAIIOO       Yes.          51.0                          1.005
# 46        MAChuligans       Yes.          52.0                          0.126
# 47           MAGLaDOS        No.          33.0                        179.664
# 48           SAaiaioh       Yes.          11.0                          0.011
# 49         SAvAIkings       Yes.        2048.0                          2.696
# 50           MAReftAI        No.           4.0                        146.170
# 51        MABoxAgents       Yes.         197.0                         25.245
# 52           SAGLaDOS        No.          46.0                        179.404
# 53         MASokoBros        No.         923.0                        179.798
# 54        SAfootsteps        No.        9150.0                        179.995
# 55         SAMSecretA       Yes.          36.0                          0.048
# 56        SADeepMinds        No.       29450.0                        179.997
# 57          SACoronAI        No.       44155.0                        179.998
# 58          SAAIstars       Yes.          41.0                          0.118
# 59             SAheav       Yes.          11.0                          0.005

# %%
temp = df1[df1['lvl_solved'] == 'Yes.'].sort_values(["actions_used"])
temp
# Out:
#              lvl_name lvl_solved  actions_used  last_action_time (in seconds)
# 10  MAOptimalSolution       Yes.           5.0                          0.044
# 59             SAheav       Yes.          11.0                          0.005
# 48           SAaiaioh       Yes.          11.0                          0.011
# 17           MAaiaioh       Yes.          13.0                          0.019
# 4              SAIIOO       Yes.          18.0                          1.573
# 27            SAThree       Yes.          21.0                          0.135
# 43           MAHoldUd       Yes.          24.0                          0.119
# 42        SAaicecubes       Yes.          27.0                          0.012
# 39          MACoronAI       Yes.          28.0                          0.092
# 18         MAMSecretA       Yes.          34.0                          0.106
# 55         SAMSecretA       Yes.          36.0                          0.048
# 58          SAAIstars       Yes.          41.0                          0.118
# 45             MAIIOO       Yes.          51.0                          1.005
# 46        MAChuligans       Yes.          52.0                          0.126
# 29         MAMAAIStro       Yes.          56.0                          0.037
# 35         MATrueGlue       Yes.          74.0                          0.310
# 23         SATrueGlue       Yes.         110.0                          0.137
# 16        MAaicecubes       Yes.         130.0                          0.207
# 19          SANicolAI       Yes.         130.0                          0.114
# 15          MANeverAI       Yes.         147.0                          1.040
# 0             MAMulle       Yes.         158.0                          0.548
# 12          SAThreePO       Yes.         164.0                          0.354
# 51        MABoxAgents       Yes.         197.0                         25.245
# 25           SATheZoo       Yes.         203.0                          0.444
# 41        MABaguettes       Yes.         213.0                         12.790
# 9         SAChuligans       Yes.         216.0                          0.333
# 8           MAThreePO       Yes.         221.0                          0.829
# 6          SADeepPlan       Yes.         337.0                          1.567
# 13          SANeverAI       Yes.         391.0                          0.405
# 2         MAdeepChaos       Yes.         451.0                          5.618
# 36            SAKaren       Yes.         497.0                         40.125
# 24        SAdeepChaos       Yes.         521.0                          5.104
# 32         MAVAikings       Yes.         866.0                        148.809
# 21         SAAIAIcapn       Yes.         941.0                         35.085
# 49         SAvAIkings       Yes.        2048.0                          2.696

# %%
ax = temp.plot(kind='scatter',x='last_action_time (in seconds)',y='actions_used',color='red')
# # plt.show()

# def label_point(x, y, val, ax):
#     a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
#     for i, point in a.iterrows():
#         ax.text(point['x'], point['y'], str(point['val']))

# label_point(ax.x, ax.y, ax.lvl_name, ax)

# draw()
