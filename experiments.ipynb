# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/mp/.local/lib/python3.8/site-packages (1.0.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/lib/python3.8/site-packages (from pandas) (1.18.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in /home/mp/.local/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv("latest-improvements-summary.csv")
print(df1)
# Out:
#              lvl_name lvl_solved  actions_used  last_action_time (in seconds)
# 0             MAMulle        No.      319215.0                         90.000
# 1           MAAIstars       Yes.         331.0                         11.011
# 2         MAdeepChaos       Yes.         451.0                          5.485
# 3             SAMulle        No.       42211.0                         89.999
# 4              SAIIOO       Yes.          21.0                          2.849
# 5          MAaiaicapn       Yes.        1168.0                          3.888
# 6          SADeepPlan       Yes.         352.0                          2.093
# 7             MAKaren        No.        2001.0                         89.893
# 8           MAThreePO       Yes.         222.0                          0.403
# 9         SAChuligans       Yes.         216.0                          0.325
# 10  MAOptimalSolution       Yes.           5.0                          0.044
# 11        MAfootsteps       Yes.         577.0                         20.947
# 12          SAThreePO       Yes.         164.0                          0.293
# 13          SANeverAI       Yes.         391.0                          0.358
# 14        SABaguettes        No.        1523.0                         86.990
# 15          MANeverAI       Yes.         143.0                          0.634
# 16        MAaicecubes       Yes.         130.0                          0.165
# 17           MAaiaioh       Yes.          13.0                          0.018
# 18         MAMSecretA       Yes.          34.0                          0.084
# 19          SANicolAI       Yes.         130.0                          0.098
# 20          MANicolAI       Yes.          87.0                          1.329
# 21         SAAIAIcapn       Yes.         933.0                          7.187
# 22           SAReftAI        No.         332.0                         86.766
# 23         SATrueGlue       Yes.         110.0                          0.117
# 24        SAdeepChaos       Yes.         521.0                          3.533
# 25           SATheZoo        No.         148.0                          0.283
# 26           SAFPHPOP        No.         382.0                         81.166
# 27            SAThree       Yes.          21.0                          0.042
# 28            MAThree       Yes.          67.0                          0.351
# 29         MAMAAIStro       Yes.          56.0                          0.032
# 30         MADeepPlan        No.      138112.0                         90.000
# 31        SAAIcaramba        No.      543401.0                         90.000
# 32         MAVAikings       Yes.         838.0                         13.381
# 33           MATheZoo       Yes.          56.0                          0.991
# 34         SASokoBros        No.      197851.0                         90.000
# 35         MATrueGlue       Yes.          81.0                          0.290
# 36            SAKaren       Yes.         497.0                         12.252
# 37           MAFPHPOP       Yes.         282.0                         22.080
# 38        MADeepMinds       Yes.          53.0                          0.062
# 39          MACoronAI       Yes.          29.0                          0.103
# 40        SABoxAgents        No.      105672.0                         90.000
# 41        MABaguettes       Yes.         213.0                          9.245
# 42        SAaicecubes       Yes.          27.0                          0.010
# 43           MAHoldUd       Yes.          30.0                          0.126
# 44           SAHoldUd        No.       53364.0                         90.000
# 45             MAIIOO       Yes.          54.0                          4.117
# 46        MAChuligans       Yes.          52.0                          0.103
# 47           MAGLaDOS       Yes.         430.0                         15.561
# 48           SAaiaioh       Yes.          11.0                          0.010
# 49         SAvAIkings       Yes.        2048.0                          1.993
# 50           MAReftAI        No.           4.0                         56.443
# 51        MABoxAgents       Yes.         191.0                          2.702
# 52           SAGLaDOS        No.          63.0                         89.802
# 53         MASokoBros        No.        1873.0                         89.962
# 54        SAfootsteps       Yes.         137.0                          1.210
# 55         SAMSecretA       Yes.          36.0                          0.044
# 56        SADeepMinds        No.      452339.0                         90.000
# 57          SACoronAI       Yes.          95.0                          0.166
# 58          SAAIstars       Yes.          41.0                          0.084
# 59             SAheav       Yes.          11.0                          0.006

# %%
temp = df1[df1['lvl_solved'] == 'Yes.'].sort_values(["actions_used"])
temp
# Out:
#              lvl_name lvl_solved  actions_used  last_action_time (in seconds)
# 10  MAOptimalSolution       Yes.           5.0                          0.044
# 59             SAheav       Yes.          11.0                          0.006
# 48           SAaiaioh       Yes.          11.0                          0.010
# 17           MAaiaioh       Yes.          13.0                          0.018
# 27            SAThree       Yes.          21.0                          0.042
# 4              SAIIOO       Yes.          21.0                          2.849
# 42        SAaicecubes       Yes.          27.0                          0.010
# 39          MACoronAI       Yes.          29.0                          0.103
# 43           MAHoldUd       Yes.          30.0                          0.126
# 18         MAMSecretA       Yes.          34.0                          0.084
# 55         SAMSecretA       Yes.          36.0                          0.044
# 58          SAAIstars       Yes.          41.0                          0.084
# 46        MAChuligans       Yes.          52.0                          0.103
# 38        MADeepMinds       Yes.          53.0                          0.062
# 45             MAIIOO       Yes.          54.0                          4.117
# 33           MATheZoo       Yes.          56.0                          0.991
# 29         MAMAAIStro       Yes.          56.0                          0.032
# 28            MAThree       Yes.          67.0                          0.351
# 35         MATrueGlue       Yes.          81.0                          0.290
# 20          MANicolAI       Yes.          87.0                          1.329
# 57          SACoronAI       Yes.          95.0                          0.166
# 23         SATrueGlue       Yes.         110.0                          0.117
# 19          SANicolAI       Yes.         130.0                          0.098
# 16        MAaicecubes       Yes.         130.0                          0.165
# 54        SAfootsteps       Yes.         137.0                          1.210
# 15          MANeverAI       Yes.         143.0                          0.634
# 12          SAThreePO       Yes.         164.0                          0.293
# 51        MABoxAgents       Yes.         191.0                          2.702
# 41        MABaguettes       Yes.         213.0                          9.245
# 9         SAChuligans       Yes.         216.0                          0.325
# 8           MAThreePO       Yes.         222.0                          0.403
# 37           MAFPHPOP       Yes.         282.0                         22.080
# 1           MAAIstars       Yes.         331.0                         11.011
# 6          SADeepPlan       Yes.         352.0                          2.093
# 13          SANeverAI       Yes.         391.0                          0.358
# 47           MAGLaDOS       Yes.         430.0                         15.561
# 2         MAdeepChaos       Yes.         451.0                          5.485
# 36            SAKaren       Yes.         497.0                         12.252
# 24        SAdeepChaos       Yes.         521.0                          3.533
# 11        MAfootsteps       Yes.         577.0                         20.947
# 32         MAVAikings       Yes.         838.0                         13.381
# 21         SAAIAIcapn       Yes.         933.0                          7.187
# 5          MAaiaicapn       Yes.        1168.0                          3.888
# 49         SAvAIkings       Yes.        2048.0                          1.993

# %%
ax = temp.plot(kind='scatter',x='last_action_time (in seconds)',y='actions_used',color='red')
# # plt.show()

# def label_point(x, y, val, ax):
#     a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
#     for i, point in a.iterrows():
#         ax.text(point['x'], point['y'], str(point['val']))

# label_point(ax.x, ax.y, ax.lvl_name, ax)

# draw()
